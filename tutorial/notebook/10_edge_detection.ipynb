# %% [markdown]
# # Gradients and edge detection

# %% [markdown]
# Firt we activate inline prining and import the necessary modules.

# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def show(img):
    # check if the image is color (dim=3) or black and white (dim=2)
    if len(img.shape)==3:
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plot = plt.imshow(img2)
    else:
        plot = plt.imshow(img, cmap='gray')

# %%
path = "../../images/coins.png"
img = cv2.imread(path)

# %%
show(img)

# %% [markdown]
# ## Laplacian

# %% [markdown]
# First we transform the color image into a grayscale image.

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
show(gray)

# %% [markdown]
# The cv2.Laplacian function calculates the gradient in 64-bit floating point. The resulting matix has positive and negative values. We use numpy absolute function to transform the negative values into positive ones.

# %%
lap = cv2.Laplacian(gray, cv2.CV_64F)
lap = np.uint8(np.absolute(lap))
show(lap)

# %% [markdown]
# ## Sobel

# %%
sobelX = cv2.Sobel(gray, cv2.CV_64F, 1, 0)
sobelY = cv2.Sobel(gray, cv2.CV_64F, 0, 1)

sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))

sobelCombined = cv2.bitwise_or(sobelX, sobelY)

# %%
show(sobelX)

# %%
show(sobelY)

# %%
show(sobelCombined)

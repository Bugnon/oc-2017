# %% [markdown]
# # Chapter 11 Contours

# %%
import numpy as np
import mahotas
import cv2
import matplotlib.pyplot as plt

def pltShow(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)

def pltShowGray(img):
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    plt.imshow(img)

image = cv2.imread("../../images/coins.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (11, 11), 0)
pltShow(image)

# %%
pltShowGray(gray)

# %%
pltShowGray(blurred)

# %% [markdown]
# ## Getting the edge

# %%
edge = cv2.Canny(blurred, 30, 150)
pltShowGray(edge)

# %% [markdown]
# ## Find the corners

# %%
(_, cnts, _) = cv2.findContours(edge.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
print("Nombre de coins trouvés : " + str(len(cnts)))

coins = image.copy()
cv2.drawContours(coins, cnts, -1, (255, 0, 255), 2)
pltShow(coins)
# Out:
# Nombre de coins trouvés : 9

# %% [markdown]
# ## Cropping

# %%
mask = np.zeros(image.shape[:2], dtype = "uint8")

liste = []

for (i, c) in enumarate(cnts):
    (x, y, w, h) = cv2.boundingRect(c)
    
    coin = image[y:y + h, x:x + w]
    
    ((centerX, centerY), radius) = cv2.minEclosingCircle(c)
    cv2.circle(mask, (int(centerX), int(centerY)), int(radius), 255, -1)
    mask = mask[y:y + h, x:x + w]
    liste.append(cv2.bitwise_and(coin, coin, mask = mask))

# %%
liste[0]

# %%
liste[1]

# %%
liste[2]

# %%
liste[3]

# %%
liste[4]

# %%
liste[5]

# %%
liste[6]

# %%
liste[7]

# %%
liste[8]

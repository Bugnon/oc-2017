# %% [markdown]
# ## Face detection

# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def show(img):
    # check if the image is color (dim=3) or black and white (dim=2)
    if len(img.shape)==3:
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plot = plt.imshow(img2)
    else:
        plot = plt.imshow(img, cmap='gray')
    # place the x-axis labels at the top
    plt.tick_params(bottom=False, top=True, labelbottom=False, labeltop=True)

# %%
def histogram(hist, title):
    plt.figure()
    plt.title(title)
    plt.xlabel("Bins")
    plt.ylabel("# of Pixels")
    plt.plot(hist)
    plt.xlim([0, 256])
    plt.show()

# %%
path = "../images/visages.jpg"
img = cv2.imread(path)
print(img.shape)
show(img)
# Out:
# (316, 474, 3)

# %%
class FaceDetector:
    def __init__(self, faceCascadePath):
        self.faceCascade = cv2.CascadeClassifier(faceCascadePath)

    def detect(self, img, scaleFactor = 1.1, minNeighbors = 5, minSize = (30, 30)):
        rects = self.faceCascade.detectMultiScale(img, scaleFactor = scaleFactor, minNeighbors = minNeighbors, minSize = minSize, flags = cv2.CASCADE_SCALE_IMAGE)

        return rects

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
fd = FaceDetector("visages.jpg")
faceRects = fd.detect(gray, scaleFactor = 1.1, minNeighbors = 5, minSize = (30, 30))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-555ccd965c04> in <module>()
#       1 fd = FaceDetector("visages.jpg")
# ----> 2 faceRects = fd.detect(gray, scaleFactor = 1.1, minNeighbors = 5, minSize = (30, 30))
#
# <ipython-input-5-81ee77803edb> in detect(self, img, scaleFactor, minNeighbors, minSize)
#       4
#       5     def detect(self, img, scaleFactor = 1.1, minNeighbors = 5, minSize = (30, 30)):
# ----> 6         rects = self.faceCascade.detectMultiScale(img, scaleFactor = scaleFactor, minNeighbors = minNeighbors, minSize = minSize, flags = cv2.CASCADE_SCALE_IMAGE)
#       7
#       8         return rects
#
# error: /home/pi/opencv-3.1.0/modules/objdetect/src/cascadedetect.cpp:1639: error: (-215) !empty() in function detectMultiScale

# %%
for (x, y, w, h) in faceRects:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

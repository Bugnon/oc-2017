# %% [markdown]
# # OpenCV Demo
#
# the first thing to do is importing the modules

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Insert a cell magic to insert images as inline elements

# %%
# %matplotlib inline

# %%
help(cv2.imread)
# Out:
# Help on built-in function imread:
#
# imread(...)
#     imread(filename[, flags]) -> retval

# %%
path ="../../fle/images/LEGO.jpg"
img =cv2.imread(path)

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (430, 640, 3)

# %% [markdown]
# In order to display a correct color image we have to convert BGR into RGB by using the "cv2.cvtColor(img.cv2.COLORBGR2RGB)

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)
